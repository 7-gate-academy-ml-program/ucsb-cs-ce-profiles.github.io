# %% [markdown]
# # Instructions:
# ## Please save a copy of this notebook to your google drive and answer the questions below.
# ## Once completed please submit your notebook to the following [GitHub Repo](https://github.com/7-gate-academy-ml-program/Synopsis)

# %% [markdown]
# ### Name: Nicholas Wickman

# %% [markdown]
# # 1.)  What is the difference between Classification and Regression?

# %% [markdown]
# Classification assigns entities into discreet classes. Regression finds a function of best fit for continuous values.

# %% [markdown]
# # 2.) What is the Curse of Dimensionality?

# %% [markdown]
# Adding dimensions to a model exponentially increases the amount of data needed for training.

# %% [markdown]
# # 3.) What is Cross Validation?

# %% [markdown]
# Partitioning a test set from your training data to test the generalization of your model, without cheating by training on the "real" test data.

# %% [markdown]
# # 4.) On a high level how do Decision  Trees work?

# %% [markdown]
# Travelling down branches of nodes and making a binary decision at each node as to what branch to follow based on a simple rule (eg. AND, OR, XOR)

# %% [markdown]
# # 5.) In regards to SVMs what is the Kernel Trick?

# %% [markdown]
# Something to do with the transpose of the input matrix and finding the least-overfit line?

# %% [markdown]
# # 6.) For an online clothes store, what are the examples of OLTP and OLAP data? (one example each)

# %% [markdown]
# OLAP: A database of products.
# OTLP: A calculation of shipping costs at checkout.

# %% [markdown]
# # 7.) Give example of a function that does not maintain Idempotency.

# %% [markdown]
# x = x + 1
